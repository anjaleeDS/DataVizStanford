# %% [markdown]
# <a href="https://colab.research.google.com/github/anjaleeDS/DataVizStanford/blob/master/04072020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello there") #shift + enter to return
# Out:
# hello there

# %%
a = "shut up"
c = 3+4
print (c)
# Out:
# 7

# %%
c = 4+5
a
# Out:
# 'shut up'

# %%
# !pip install --upgrade -q gspread

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for name, value in globals().copy().items():
  print(name, value)
# Out:
# __name__ __main__
# __doc__ Automatically created module for IPython interactive environment
# __package__ None
# __loader__ None
# __spec__ None
# __builtin__ <module 'builtins' (built-in)>
# __builtins__ <module 'builtins' (built-in)>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from vega_datasets import data

cars_data = data.cars()
print(cars_data)
# Out:
#                           Name  Miles_per_Gallon  ...       Year  Origin
# 0    chevrolet chevelle malibu              18.0  ... 1970-01-01     USA
# 1            buick skylark 320              15.0  ... 1970-01-01     USA
# 2           plymouth satellite              18.0  ... 1970-01-01     USA
# 3                amc rebel sst              16.0  ... 1970-01-01     USA
# 4                  ford torino              17.0  ... 1970-01-01     USA
# ..                         ...               ...  ...        ...     ...
# 401            ford mustang gl              27.0  ... 1982-01-01     USA
# 402                  vw pickup              44.0  ... 1982-01-01  Europe
# 403              dodge rampage              32.0  ... 1982-01-01     USA
# 404                ford ranger              28.0  ... 1982-01-01     USA
# 405                 chevy s-10              31.0  ... 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
scatter = sns.scatterplot(data.birdstrikes)
scatter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-934c1d84214b> in <module>()
# ----> 1 scatter = sns.scatterplot(data.birdstrikes)
#       2 scatter
#
# /usr/local/lib/python3.6/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...

# %%
cars_data
# Out:
#                           Name  Miles_per_Gallon  ...       Year  Origin
# 0    chevrolet chevelle malibu              18.0  ... 1970-01-01     USA
# 1            buick skylark 320              15.0  ... 1970-01-01     USA
# 2           plymouth satellite              18.0  ... 1970-01-01     USA
# 3                amc rebel sst              16.0  ... 1970-01-01     USA
# 4                  ford torino              17.0  ... 1970-01-01     USA
# ..                         ...               ...  ...        ...     ...
# 401            ford mustang gl              27.0  ... 1982-01-01     USA
# 402                  vw pickup              44.0  ... 1982-01-01  Europe
# 403              dodge rampage              32.0  ... 1982-01-01     USA
# 404                ford ranger              28.0  ... 1982-01-01     USA
# 405                 chevy s-10              31.0  ... 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
gh=data.github()
gh
# Out:
#                    time  count
# 0   2015-01-01 01:00:00      2
# 1   2015-01-01 04:00:00      3
# 2   2015-01-01 05:00:00      1
# 3   2015-01-01 08:00:00      1
# 4   2015-01-01 09:00:00      3
# ..                  ...    ...
# 950 2015-05-29 17:00:00      1
# 951 2015-05-29 19:00:00      1
# 952 2015-05-30 00:00:00     10
# 953 2015-05-30 09:00:00      1
# 954 2015-05-30 11:00:00      2
#
# [955 rows x 2 columns]

# %%
airports = data.airports()

# %%
airports
# Out:
#      iata                       name  ...   latitude   longitude
# 0     00M                    Thigpen  ...  31.953765  -89.234505
# 1     00R       Livingston Municipal  ...  30.685861  -95.017928
# 2     00V                Meadow Lake  ...  38.945749 -104.569893
# 3     01G               Perry-Warsaw  ...  42.741347  -78.052081
# 4     01J           Hilliard Airpark  ...  30.688012  -81.905944
# ...   ...                        ...  ...        ...         ...
# 3371  ZEF            Elkin Municipal  ...  36.280024  -80.786069
# 3372  ZER  Schuylkill Cty/Joe Zerbey  ...  40.706449  -76.373147
# 3373  ZPH      Zephyrhills Municipal  ...  28.228065  -82.155916
# 3374  ZUN                 Black Rock  ...  35.083227 -108.791777
# 3375  ZZV       Zanesville Municipal  ...  39.944458  -81.892105
#
# [3376 rows x 7 columns]

# %%
stuff = data.udistrict()
stuff
# Out:
#           key        lat
# 0    bakeries  47.668870
# 1    bakeries  47.661781
# 2    bakeries  47.659980
# 3    bakeries  47.663373
# 4    bakeries  47.658210
# ..        ...        ...
# 177    coffee  47.654667
# 178    coffee  47.661621
# 179    coffee  47.662790
# 180    coffee  47.656376
# 181    coffee  47.656833
#
# [182 rows x 2 columns]

# %%
# !hostname
# Out:
# 6cb8374cc01c

# %%
cars_data
# Out:
#                           Name  Miles_per_Gallon  ...       Year  Origin
# 0    chevrolet chevelle malibu              18.0  ... 1970-01-01     USA
# 1            buick skylark 320              15.0  ... 1970-01-01     USA
# 2           plymouth satellite              18.0  ... 1970-01-01     USA
# 3                amc rebel sst              16.0  ... 1970-01-01     USA
# 4                  ford torino              17.0  ... 1970-01-01     USA
# ..                         ...               ...  ...        ...     ...
# 401            ford mustang gl              27.0  ... 1982-01-01     USA
# 402                  vw pickup              44.0  ... 1982-01-01  Europe
# 403              dodge rampage              32.0  ... 1982-01-01     USA
# 404                ford ranger              28.0  ... 1982-01-01     USA
# 405                 chevy s-10              31.0  ... 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(cars_data.Horsepower, cars_data.Miles_per_Gallon)
plt.title('first scatter plot')
plt.xlabel('HP')
plt.ylabel('MPG')
plt.show() #this will get rid of the extra text that this usually print

# %%
cars_data.Origin.unique()
# Out:
# array(['USA', 'Europe', 'Japan'], dtype=object)

# %%
cars_data.Origin.value_counts()
# Out:
# USA       254
# Japan      79
# Europe     73
# Name: Origin, dtype: int64

# %%
for region in cars_data.Origin.unique():
  data_subset = cars_data[cars_data.Origin==region]
  plt.scatter(data_subset.Horsepower, data_subset.Miles_per_Gallon, label=region)

plt.title('second scatter plot')
plt.xlabel('HP')
plt.ylabel('MPG')
plt.legend()
plt.show() #this will get rid of the extra text that this usually print
# https://colab.research.google.com/drive/14KhPbAMJtkYJvk-J0XlXUwImNjyMiKDQ#scrollTo=o5KhLE311ZsO

# %%
import seaborn as sns
sns.scatterplot(x='Horsepower', y='Miles_per_Gallon', data=cars_data, hue='Origin') #hue gives the slicing and legend

plt.show()

# %%
sns.pairplot(cars_data)

# %%
sns.set_color_codes(palette='deep')

# %%
jobs = data.jobs()

# %%
data.jobs.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-c08801a4951d> in <module>()
# ----> 1 data.jobs.columns()
#
# AttributeError: 'Dataset' object has no attribute 'columns'

# %%
jobs.columns.unique()
# Out:
# Index(['job', 'sex', 'year', 'count', 'perc'], dtype='object')

# %%
#homework:
# use a fixed notebook
# use the movies data
# create a data plt using google photos album and add a link to your notebook!
